# %% [markdown]
# ## Leitura do Dataset M5

# %% [markdown]
# ## Produtos

# %%
import pandas as pd

base_url = 'https://datasets-nixtla.s3.amazonaws.com'
Y_df = pd.read_parquet(f'{base_url}/m5_y.parquet')

# %%
Y_df
# Out:
#                      unique_id         ds    y
# 0             FOODS_1_001_CA_1 2011-01-29  3.0
# 1             FOODS_1_001_CA_1 2011-01-30  0.0
# 2             FOODS_1_001_CA_1 2011-01-31  0.0
# 3             FOODS_1_001_CA_1 2011-02-01  1.0
# 4             FOODS_1_001_CA_1 2011-02-02  4.0
# ...                        ...        ...  ...
# 47649935  HOUSEHOLD_2_516_WI_3 2016-06-15  0.0
# 47649936  HOUSEHOLD_2_516_WI_3 2016-06-16  1.0
# 47649937  HOUSEHOLD_2_516_WI_3 2016-06-17  0.0
# 47649938  HOUSEHOLD_2_516_WI_3 2016-06-18  0.0
# 47649939  HOUSEHOLD_2_516_WI_3 2016-06-19  0.0
#
# [47649940 rows x 3 columns]

# %%
Y_df['unique_id'].unique()
# Out:
# ['FOODS_1_001_CA_1', 'FOODS_1_001_CA_2', 'FOODS_1_001_CA_3', 'FOODS_1_001_CA_4', 'FOODS_1_001_TX_1', ..., 'HOUSEHOLD_2_516_TX_2', 'HOUSEHOLD_2_516_TX_3', 'HOUSEHOLD_2_516_WI_1', 'HOUSEHOLD_2_516_WI_2', 'HOUSEHOLD_2_516_WI_3']
# Length: 30490
# Categories (30490, object): ['FOODS_1_001_CA_1', 'FOODS_1_001_CA_2', 'FOODS_1_001_CA_3',
#                              'FOODS_1_001_CA_4', ..., 'HOUSEHOLD_2_516_TX_3', 'HOUSEHOLD_2_516_WI_1',
#                              'HOUSEHOLD_2_516_WI_2', 'HOUSEHOLD_2_516_WI_3']

# %% [markdown]
# ## Exemplo: Seleção do Departamento Hobbies 2 da Loja CA 1 - 149 séries temporais
#
# Nota: Os alunos deverão escolher outro departamento que não este.

# %%
Y_df_HOBBIES2 = Y_df[Y_df['unique_id'].str.startswith('HOBBIES_2')]
Y_df_HOBBIES2_CA1 = Y_df_HOBBIES2[Y_df_HOBBIES2['unique_id'].str.endswith('CA_1')]
Y_df_HOBBIES2_CA1
# Out:
#                    unique_id         ds    y
# 28852365  HOBBIES_2_001_CA_1 2011-01-29  1.0
# 28852366  HOBBIES_2_001_CA_1 2011-01-30  0.0
# 28852367  HOBBIES_2_001_CA_1 2011-01-31  0.0
# 28852368  HOBBIES_2_001_CA_1 2011-02-01  0.0
# 28852369  HOBBIES_2_001_CA_1 2011-02-02  0.0
# ...                      ...        ...  ...
# 31092533  HOBBIES_2_149_CA_1 2016-06-15  0.0
# 31092534  HOBBIES_2_149_CA_1 2016-06-16  0.0
# 31092535  HOBBIES_2_149_CA_1 2016-06-17  0.0
# 31092536  HOBBIES_2_149_CA_1 2016-06-18  0.0
# 31092537  HOBBIES_2_149_CA_1 2016-06-19  0.0
#
# [229077 rows x 3 columns]

# %% [markdown]
# ## Conjunto de Treino e Teste

# %%
train = Y_df_HOBBIES2_CA1[Y_df_HOBBIES2_CA1['ds'] <= '2016-05-22']
train
# Out:
#                    unique_id         ds    y
# 28852365  HOBBIES_2_001_CA_1 2011-01-29  1.0
# 28852366  HOBBIES_2_001_CA_1 2011-01-30  0.0
# 28852367  HOBBIES_2_001_CA_1 2011-01-31  0.0
# 28852368  HOBBIES_2_001_CA_1 2011-02-01  0.0
# 28852369  HOBBIES_2_001_CA_1 2011-02-02  0.0
# ...                      ...        ...  ...
# 31092505  HOBBIES_2_149_CA_1 2016-05-18  0.0
# 31092506  HOBBIES_2_149_CA_1 2016-05-19  0.0
# 31092507  HOBBIES_2_149_CA_1 2016-05-20  0.0
# 31092508  HOBBIES_2_149_CA_1 2016-05-21  0.0
# 31092509  HOBBIES_2_149_CA_1 2016-05-22  0.0
#
# [224905 rows x 3 columns]

# %%
test = Y_df_HOBBIES2_CA1[Y_df_HOBBIES2_CA1['ds'] > '2016-05-22']
test
# Out:
#                    unique_id         ds    y
# 28854306  HOBBIES_2_001_CA_1 2016-05-23  0.0
# 28854307  HOBBIES_2_001_CA_1 2016-05-24  0.0
# 28854308  HOBBIES_2_001_CA_1 2016-05-25  0.0
# 28854309  HOBBIES_2_001_CA_1 2016-05-26  0.0
# 28854310  HOBBIES_2_001_CA_1 2016-05-27  0.0
# ...                      ...        ...  ...
# 31092533  HOBBIES_2_149_CA_1 2016-06-15  0.0
# 31092534  HOBBIES_2_149_CA_1 2016-06-16  0.0
# 31092535  HOBBIES_2_149_CA_1 2016-06-17  0.0
# 31092536  HOBBIES_2_149_CA_1 2016-06-18  0.0
# 31092537  HOBBIES_2_149_CA_1 2016-06-19  0.0
#
# [4172 rows x 3 columns]

# %% [markdown]
# ## Regressores

# %%
X_df = pd.read_parquet(f'{base_url}/m5_x.parquet')

# %%
X_df
# Out:
#                      unique_id         ds  event_name_1 event_type_1  \
# 0             FOODS_1_001_CA_1 2011-01-29           nan          nan
# 1             FOODS_1_001_CA_1 2011-01-30           nan          nan
# 2             FOODS_1_001_CA_1 2011-01-31           nan          nan
# 3             FOODS_1_001_CA_1 2011-02-01           nan          nan
# 4             FOODS_1_001_CA_1 2011-02-02           nan          nan
# ...                        ...        ...           ...          ...
# 47649935  HOUSEHOLD_2_516_WI_3 2016-06-15           nan          nan
# 47649936  HOUSEHOLD_2_516_WI_3 2016-06-16           nan          nan
# 47649937  HOUSEHOLD_2_516_WI_3 2016-06-17           nan          nan
# 47649938  HOUSEHOLD_2_516_WI_3 2016-06-18           nan          nan
# 47649939  HOUSEHOLD_2_516_WI_3 2016-06-19  NBAFinalsEnd     Sporting
#
#           event_name_2 event_type_2  snap_CA  snap_TX  snap_WI  sell_price
# ...

# %%
X_df_HOBBIES2 = X_df[X_df['unique_id'].str.startswith('HOBBIES_2')]
X_df_HOBBIES2_CA1 = X_df_HOBBIES2[X_df_HOBBIES2['unique_id'].str.endswith('CA_1')]
X_df_HOBBIES2_CA1
# Out:
#                    unique_id         ds  event_name_1 event_type_1  \
# 28852365  HOBBIES_2_001_CA_1 2011-01-29           nan          nan
# 28852366  HOBBIES_2_001_CA_1 2011-01-30           nan          nan
# 28852367  HOBBIES_2_001_CA_1 2011-01-31           nan          nan
# 28852368  HOBBIES_2_001_CA_1 2011-02-01           nan          nan
# 28852369  HOBBIES_2_001_CA_1 2011-02-02           nan          nan
# ...                      ...        ...           ...          ...
# 31092533  HOBBIES_2_149_CA_1 2016-06-15           nan          nan
# 31092534  HOBBIES_2_149_CA_1 2016-06-16           nan          nan
# 31092535  HOBBIES_2_149_CA_1 2016-06-17           nan          nan
# 31092536  HOBBIES_2_149_CA_1 2016-06-18           nan          nan
# 31092537  HOBBIES_2_149_CA_1 2016-06-19  NBAFinalsEnd     Sporting
#
#           event_name_2 event_type_2  snap_CA  snap_TX  snap_WI  sell_price
# 28852365           nan          nan        0        0        0        5.47
# ...

# %%
regressors_train = X_df_HOBBIES2_CA1[X_df_HOBBIES2_CA1['ds'] <= '2016-05-22']
regressors_train
# Out:
#                    unique_id         ds event_name_1 event_type_1  \
# 28852365  HOBBIES_2_001_CA_1 2011-01-29          nan          nan
# 28852366  HOBBIES_2_001_CA_1 2011-01-30          nan          nan
# 28852367  HOBBIES_2_001_CA_1 2011-01-31          nan          nan
# 28852368  HOBBIES_2_001_CA_1 2011-02-01          nan          nan
# 28852369  HOBBIES_2_001_CA_1 2011-02-02          nan          nan
# ...                      ...        ...          ...          ...
# 31092505  HOBBIES_2_149_CA_1 2016-05-18          nan          nan
# 31092506  HOBBIES_2_149_CA_1 2016-05-19          nan          nan
# 31092507  HOBBIES_2_149_CA_1 2016-05-20          nan          nan
# 31092508  HOBBIES_2_149_CA_1 2016-05-21          nan          nan
# 31092509  HOBBIES_2_149_CA_1 2016-05-22          nan          nan
#
#          event_name_2 event_type_2  snap_CA  snap_TX  snap_WI  sell_price
# 28852365          nan          nan        0        0        0        5.47
# ...

# %%
regressors_test = X_df_HOBBIES2_CA1[X_df_HOBBIES2_CA1['ds'] > '2016-05-22']
regressors_test
# Out:
#                    unique_id         ds  event_name_1 event_type_1  \
# 28854306  HOBBIES_2_001_CA_1 2016-05-23           nan          nan
# 28854307  HOBBIES_2_001_CA_1 2016-05-24           nan          nan
# 28854308  HOBBIES_2_001_CA_1 2016-05-25           nan          nan
# 28854309  HOBBIES_2_001_CA_1 2016-05-26           nan          nan
# 28854310  HOBBIES_2_001_CA_1 2016-05-27           nan          nan
# ...                      ...        ...           ...          ...
# 31092533  HOBBIES_2_149_CA_1 2016-06-15           nan          nan
# 31092534  HOBBIES_2_149_CA_1 2016-06-16           nan          nan
# 31092535  HOBBIES_2_149_CA_1 2016-06-17           nan          nan
# 31092536  HOBBIES_2_149_CA_1 2016-06-18           nan          nan
# 31092537  HOBBIES_2_149_CA_1 2016-06-19  NBAFinalsEnd     Sporting
#
#           event_name_2 event_type_2  snap_CA  snap_TX  snap_WI  sell_price
# 28854306           nan          nan        0        0        0        5.47
# ...
